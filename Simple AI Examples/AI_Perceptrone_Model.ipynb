# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from PIL import Image

# Загрузка данных MNIST
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Предобработка данных
x_train = x_train / 255.0
x_test = x_test / 255.0

# Создание модели нейронной сети
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
])

# Компиляция модели
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Обучение модели
model.fit(x_train, y_train, epochs=5)

# Оценка точности модели на тестовых данных
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Точность на тестовых данных:', test_acc)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2956 - accuracy: 0.9137
# Epoch 2/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1395 - accuracy: 0.9587
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1030 - accuracy: 0.9688
# Epoch 4/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0849 - accuracy: 0.9741
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0721 - accuracy: 0.9774
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0777 - accuracy: 0.9757
# Точность на тестовых данных: 0.9757000207901001

# %%
# Загрузка и предобработка изображения
image = Image.open('/content/Снимок экрана 2023-07-08 173209.png').convert('L')
image = image.resize((28, 28))
image = tf.keras.preprocessing.image.img_to_array(image)
image = image / 255.0
image = image.reshape(1, 28, 28)

# Предсказание цифры
prediction = model.predict(image)
digit = tf.argmax(prediction, axis=1)[0]

print('Предсказанная цифра:', digit)
# Out:
# 1/1 [==============================] - 0s 59ms/step
# Предсказанная цифра: tf.Tensor(7, shape=(), dtype=int64)
